# %% [markdown]
# ## Use Habanero to Query Information on DOIs from USGS Spreadsheet
#
# This notebook uses the Python package called [habanero](https://habanero.readthedocs.io/en/latest/modules/crossref.html) to query the [CrossRef Database API](https://github.com/CrossRef/rest-api-doc) for information on USGS DOIs for data releases and the package called [pprintjson](https://github.com/clarketm/pprintjson) for easy viewing of the query results.
#
# These packages can easily be installed using `pip install habanero` and `pip install pprintjson`.
#
# USGS has a spreadsheet that contains the data release DOI (column called dr_doi) and the DOI for the publication associated with the data release (column called rel_pub_url).
#
# One goal is to auto-populate the spreadsheet with the following information about the rel_pub_url:
# * title
# * journal name
# * year of publication
# * publisher
#
# However, the primary goal is to identify whether the data release doi (dr_doi) is actually cited within the publication (rel_pub_url), and if so, document where it is cited (e.g. references section, main text body, figure caption).
#
# Searching of the references can be completed with habanero for those publications that have a reference list available in CrossRef.
#
# Per the Habanero documentation on the CrossRef API:
# > When you search with query terms, on Crossref servers, it will not search full text, or even abstracts of articles, but only what is available in the API data response options. That is, it searches titles, authors, year of publication, reference list (if one is available), etc. For some discussion on this, see https://github.com/CrossRef/rest-api-doc/issues/101

# %%
# Import packages
from pprintjson import pprintjson as ppjson 
import pandas as pd
from habanero import Crossref

# %%
# Code below adapted from:
# https://habanero.readthedocs.io/en/latest/modules/crossref.html#habanero.Crossref.works
cr = Crossref()

# %% [markdown]
# ### Example of Publication Without Full Reference List

# %%
# Example publication: https://api.crossref.org/works/10.1021/acs.est.8b07227

# First row from USGS spreadsheet:
# 2019; journal title in spreadsheet: ACS Publications/Environmental Science and Technology
result = cr.works(ids = '10.1021/acs.est.8b07227')

# %%
# Use prettyprint to see results more easily
ppjson(result)
# Out:
# {
#     "status": "ok",
#     "message-type": "work",
#     "message-version": "1.0.0",
#     "message": {
#         "indexed": {
#             "date-parts": [
#                 [
#                     2020,
#                     4,
#                     24
#                 ]
#             ],
#             "date-time": "2020-04-24T19:23:29Z",
#             "timestamp": 1587756209612
#         },
#         "reference-count": 67,
#         "publisher": "American Chemical Society (ACS)",
#         "issue": "9",
#         "funder": [
#             {
#                 "DOI": "10.13039/100007149",
#                 "name": "U.S. Bureau of Land Management",
#                 "doi-asserted-by": "publisher",
#                 "award": []
#             },
#             {
#                 "DOI": "10.13039/100000203",
#                 "name": "U.S. Geological Survey",
#                 "doi-asserted-by": "publisher",
#                 "award": []
#             }
#         ],
#         "content-domain": {
#             "domain": [],
#             "crossmark-restriction": false
#         },
#         "short-container-title": [
#             "Environ. Sci. Technol."
#         ],
#         "published-print": {
#             "date-parts": [
#                 [
#                     2019,
#                     5,
#                     7
#                 ]
#             ]
#         },
#         "DOI": "10.1021/acs.est.8b07227",
#         "type": "journal-article",
#         "created": {
#             "date-parts": [
#                 [
#                     2019,
#                     3,
#                     29
#                 ]
#             ],
#             "date-time": "2019-03-29T10:53:35Z",
#             "timestamp": 1553856815000
#         },
#         "page": "5396-5405",
#         "source": "Crossref",
#         "is-referenced-by-count": 2,
#         "title": [
#             "Mercury Exposure and Altered Parental Nesting Behavior in a Wild Songbird"
#         ],
#         "prefix": "10.1021",
#         "volume": "53",
#         "author": [
#             {
#                 "ORCID": "http://orcid.org/0000-0002-7222-1633",
#                 "authenticated-orcid": true,
#                 "given": "C. Alex",
#                 "family": "Hartman",
#                 "sequence": "first",
#                 "affiliation": [
#                     {
#                         "name": "U.S. Geological Survey, Western Ecological Research Center, Dixon Field Station, 800 Business Park Drive, Suite D, Dixon, California 95620, United States"
#                     }
#                 ]
#             },
#             {
#                 "ORCID": "http://orcid.org/0000-0002-3074-8322",
#                 "authenticated-orcid": true,
#                 "given": "Joshua T.",
#                 "family": "Ackerman",
#                 "sequence": "additional",
#                 "affiliation": [
#                     {
#                         "name": "U.S. Geological Survey, Western Ecological Research Center, Dixon Field Station, 800 Business Park Drive, Suite D, Dixon, California 95620, United States"
#                     }
#                 ]
#             },
#             {
#                 "given": "Mark P.",
#                 "family": "Herzog",
#                 "sequence": "additional",
#                 "affiliation": [
#                     {
#                         "name": "U.S. Geological Survey, Western Ecological Research Center, Dixon Field Station, 800 Business Park Drive, Suite D, Dixon, California 95620, United States"
#                     }
#                 ]
#             }
#         ],
#         "member": "316",
#         "published-online": {
#             "date-parts": [
#                 [
#                     2019,
#                     3,
#                     29
#                 ]
#             ]
#         },
#         "container-title": [
#             "Environmental Science & Technology"
#         ],
#         "original-title": [],
#         "language": "en",
#         "link": [
#             {
#                 "URL": "https://pubs.acs.org/doi/pdf/10.1021/acs.est.8b07227",
#                 "content-type": "unspecified",
#                 "content-version": "vor",
#                 "intended-application": "similarity-checking"
#             }
#         ],
#         "deposited": {
#             "date-parts": [
#                 [
#                     2020,
#                     4,
#                     9
#                 ]
#             ],
#             "date-time": "2020-04-09T16:16:29Z",
#             "timestamp": 1586448989000
#         },
#         "score": 1.0,
#         "subtitle": [],
#         "short-title": [],
#         "issued": {
#             "date-parts": [
#                 [
#                     2019,
#                     3,
#                     29
#                 ]
#             ]
#         },
#         "references-count": 67,
#         "journal-issue": {
#             "published-online": {
#                 "date-parts": [
#                     [
#                         2019,
#                         4,
#                         19
#                     ]
#                 ]
#             },
#             "published-print": {
#                 "date-parts": [
#                     [
#                         2019,
#                         5,
#                         7
#                     ]
#                 ]
#             },
#             "issue": "9"
#         },
#         "alternative-id": [
#             "10.1021/acs.est.8b07227"
#         ],
#         "URL": "http://dx.doi.org/10.1021/acs.est.8b07227",
#         "relation": {},
#         "ISSN": [
#             "0013-936X",
#             "1520-5851"
#         ],
#         "issn-type": [
#             {
#                 "value": "0013-936X",
#                 "type": "print"
#             },
#             {
#                 "value": "1520-5851",
#                 "type": "electronic"
#             }
#         ],
#         "subject": [
#             "General Chemistry",
#             "Environmental Chemistry"
#         ]
#     }
# }

# %%
# Most relevant information contained within "message"
ppjson(result["message"])
# Out:
# {
#     "indexed": {
#         "date-parts": [
#             [
#                 2020,
#                 4,
#                 24
#             ]
#         ],
#         "date-time": "2020-04-24T19:23:29Z",
#         "timestamp": 1587756209612
#     },
#     "reference-count": 67,
#     "publisher": "American Chemical Society (ACS)",
#     "issue": "9",
#     "funder": [
#         {
#             "DOI": "10.13039/100007149",
#             "name": "U.S. Bureau of Land Management",
#             "doi-asserted-by": "publisher",
#             "award": []
#         },
#         {
#             "DOI": "10.13039/100000203",
#             "name": "U.S. Geological Survey",
#             "doi-asserted-by": "publisher",
#             "award": []
#         }
#     ],
#     "content-domain": {
#         "domain": [],
#         "crossmark-restriction": false
#     },
#     "short-container-title": [
#         "Environ. Sci. Technol."
#     ],
#     "published-print": {
#         "date-parts": [
#             [
#                 2019,
#                 5,
#                 7
#             ]
#         ]
#     },
#     "DOI": "10.1021/acs.est.8b07227",
#     "type": "journal-article",
#     "created": {
#         "date-parts": [
#             [
#                 2019,
#                 3,
#                 29
#             ]
#         ],
#         "date-time": "2019-03-29T10:53:35Z",
#         "timestamp": 1553856815000
#     },
#     "page": "5396-5405",
#     "source": "Crossref",
#     "is-referenced-by-count": 2,
#     "title": [
#         "Mercury Exposure and Altered Parental Nesting Behavior in a Wild Songbird"
#     ],
#     "prefix": "10.1021",
#     "volume": "53",
#     "author": [
#         {
#             "ORCID": "http://orcid.org/0000-0002-7222-1633",
#             "authenticated-orcid": true,
#             "given": "C. Alex",
#             "family": "Hartman",
#             "sequence": "first",
#             "affiliation": [
#                 {
#                     "name": "U.S. Geological Survey, Western Ecological Research Center, Dixon Field Station, 800 Business Park Drive, Suite D, Dixon, California 95620, United States"
#                 }
#             ]
#         },
#         {
#             "ORCID": "http://orcid.org/0000-0002-3074-8322",
#             "authenticated-orcid": true,
#             "given": "Joshua T.",
#             "family": "Ackerman",
#             "sequence": "additional",
#             "affiliation": [
#                 {
#                     "name": "U.S. Geological Survey, Western Ecological Research Center, Dixon Field Station, 800 Business Park Drive, Suite D, Dixon, California 95620, United States"
#                 }
#             ]
#         },
#         {
#             "given": "Mark P.",
#             "family": "Herzog",
#             "sequence": "additional",
#             "affiliation": [
#                 {
#                     "name": "U.S. Geological Survey, Western Ecological Research Center, Dixon Field Station, 800 Business Park Drive, Suite D, Dixon, California 95620, United States"
#                 }
#             ]
#         }
#     ],
#     "member": "316",
#     "published-online": {
#         "date-parts": [
#             [
#                 2019,
#                 3,
#                 29
#             ]
#         ]
#     },
#     "container-title": [
#         "Environmental Science & Technology"
#     ],
#     "original-title": [],
#     "language": "en",
#     "link": [
#         {
#             "URL": "https://pubs.acs.org/doi/pdf/10.1021/acs.est.8b07227",
#             "content-type": "unspecified",
#             "content-version": "vor",
#             "intended-application": "similarity-checking"
#         }
#     ],
#     "deposited": {
#         "date-parts": [
#             [
#                 2020,
#                 4,
#                 9
#             ]
#         ],
#         "date-time": "2020-04-09T16:16:29Z",
#         "timestamp": 1586448989000
#     },
#     "score": 1.0,
#     "subtitle": [],
#     "short-title": [],
#     "issued": {
#         "date-parts": [
#             [
#                 2019,
#                 3,
#                 29
#             ]
#         ]
#     },
#     "references-count": 67,
#     "journal-issue": {
#         "published-online": {
#             "date-parts": [
#                 [
#                     2019,
#                     4,
#                     19
#                 ]
#             ]
#         },
#         "published-print": {
#             "date-parts": [
#                 [
#                     2019,
#                     5,
#                     7
#                 ]
#             ]
#         },
#         "issue": "9"
#     },
#     "alternative-id": [
#         "10.1021/acs.est.8b07227"
#     ],
#     "URL": "http://dx.doi.org/10.1021/acs.est.8b07227",
#     "relation": {},
#     "ISSN": [
#         "0013-936X",
#         "1520-5851"
#     ],
#     "issn-type": [
#         {
#             "value": "0013-936X",
#             "type": "print"
#         },
#         {
#             "value": "1520-5851",
#             "type": "electronic"
#         }
#     ],
#     "subject": [
#         "General Chemistry",
#         "Environmental Chemistry"
#     ]
# }

# %%
# Get publication DOI
result["message"]["DOI"]
# Out:
# '10.1021/acs.est.8b07227'

# %%
# Get publication date
result["message"]["published-online"]["date-parts"][0]
# Out:
# [2019, 3, 29]

# %%
# Get year from publication date
result["message"]["published-online"]["date-parts"][0][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6da02a2732c0> in <module>
#       1 # Get year from publication date
# ----> 2 result["message"]["published-online"]["date-parts"][0][0]
#
# NameError: name 'result' is not defined

# %%
# Get title of publication
result["message"]["title"][0]
# Out:
# 'Mercury Exposure and Altered Parental Nesting Behavior in a Wild Songbird'

# %%
# Get publisher
result["message"]["publisher"]
# Out:
# 'American Chemical Society (ACS)'

# %%
# This example contains reference count but not list of references  
result["message"]["references-count"]
# Out:
# 67

# %%
# Code does not execute because this info is not available for this publication
#result["message"]["reference"]

# %% [markdown]
# ### Example of Publication With Full Reference List

# %%
# Second row from USGS spreadsheet:
# 2017 journal title in spreadsheet: Changes in Community
result = cr.works(ids = 'https://doi.org/10.1007/s13157-017-0895-3')

# %%
# Get publication DOI
result["message"]["DOI"]
# Out:
# '10.1007/s13157-017-0895-3'

# %%
# Reference-count was accurate: 
# 89 from https://link.springer.com/article/10.1007/s13157-017-0895-3#Bib1 
result["message"]["references-count"]
# Out:
# 89

# %%
# This example contains the actual list of references
# Note key for last entry in reference: "key": "895_CR89"
ppjson(result["message"]["reference"])
# Out:
# [
#     {
#         "key": "895_CR1",
#         "unstructured": "Baldwin BG (2002) The Jepson Desert manual: vascular plants of southeastern California. Univ of California Press, Oakland CA"
#     },
#     {
#         "key": "895_CR2",
#         "doi-asserted-by": "crossref",
#         "first-page": "1533",
#         "DOI": "10.1111/j.0030-1299.2008.16776.x",
#         "volume": "117",
#         "author": "M Bernhardt-R\u00f6mermann",
#         "year": "2008",
#         "unstructured": "Bernhardt-R\u00f6mermann M, R\u00f6mermann C, Nuske R, Parth A, Klotz S, Schmidt W, Stadler J (2008) On the identification of the most suitable traits for plant functional trait analyses. Oikos 117:1533\u20131541",
#         "journal-title": "Oikos"
#     },
#     {
#         "key": "895_CR3",
#         "doi-asserted-by": "crossref",
#         "first-page": "287",
#         "DOI": "10.1007/BF00540195",
#         "volume": "45",
#         "author": "TW Boutton",
#         "year": "1980",
#         "unstructured": "Boutton TW, Harrison AT, Smith BN (1980) Distribution of biomass of species differing in photosynthetic pathway along an altitudinal transect in southeastern Wyoming grassland. Oecologia 45:287\u2013298",
#         "journal-title": "Oecologia"
#     },
#     {
#         "key": "895_CR4",
#         "unstructured": "Box GE, Cox DR (1964) An analysis of transformations. Journal of the Royal Statistical Society. Series B (Methodological) 26(2):211-252"
#     },
#     {
#         "key": "895_CR5",
#         "doi-asserted-by": "crossref",
#         "first-page": "891",
#         "DOI": "10.1093/treephys/24.8.891",
#         "volume": "24",
#         "author": "SJ Bucci",
#         "year": "2004",
#         "unstructured": "Bucci SJ, Goldstein G, Meinzer FC, Scholz FG, Franco AC, Bustamante M (2004) Functional convergence in hydraulic architecture and water relations of tropical savanna trees: from leaf to whole plant. Tree Physiology 24:891\u2013899",
#         "journal-title": "Tree Physiology"
#     },
#     {
#         "key": "895_CR6",
#         "doi-asserted-by": "crossref",
#         "first-page": "351",
#         "DOI": "10.1111/j.1461-0248.2009.01285.x",
#         "volume": "12",
#         "author": "J Chave",
#         "year": "2009",
#         "unstructured": "Chave J, Coomes D, Jansen S, Lewis SL, Swenson NG, Zanne AE (2009) Towards a worldwide wood economics spectrum. Ecology Letters 12:351\u2013366",
#         "journal-title": "Ecology Letters"
#     },
#     {
#         "key": "895_CR7",
#         "doi-asserted-by": "crossref",
#         "first-page": "1979",
#         "DOI": "10.1002/ecy.1453",
#         "volume": "97",
#         "author": "JS Clark",
#         "year": "2016",
#         "unstructured": "Clark JS (2016) Why species tell more about traits than traits about species: predictive analysis. Ecology 97:1979\u20131993",
#         "journal-title": "Ecology"
#     },
#     {
#         "key": "895_CR8",
#         "doi-asserted-by": "crossref",
#         "first-page": "109",
#         "DOI": "10.1890/07-1134.1",
#         "volume": "79",
#         "author": "WK Cornwell",
#         "year": "2009",
#         "unstructured": "Cornwell WK, Ackerly DD (2009) Community assembly and shifts in plant trait distributions across an environmental gradient in coastal California. Ecological Monographs 79:109\u2013126",
#         "journal-title": "Ecological Monographs"
#     },
#     {
#         "key": "895_CR9",
#         "doi-asserted-by": "crossref",
#         "first-page": "1465",
#         "DOI": "10.1890/0012-9658(2006)87[1465:ATTFHF]2.0.CO;2",
#         "volume": "87",
#         "author": "WK Cornwell",
#         "year": "2006",
#         "unstructured": "Cornwell WK, Schwilk DW, Ackerly DD (2006) A trait-based test for habitat filtering: convex hull volume. Ecology 87:1465\u20131471",
#         "journal-title": "Ecology"
#     },
#     {
#         "key": "895_CR10",
#         "unstructured": "Connell JH (1978) Diversity in tropical rain forests and coral reefs. Science 199:1302-1310",
#         "DOI": "10.1126/science.199.4335.1302",
#         "doi-asserted-by": "crossref"
#     },
#     {
#         "key": "895_CR11",
#         "unstructured": "Diaz S, Kattge J, Cornelissen JHC, Wright IJ, Lavorel S et al (2016) The global spectrum of plant form and function. Nature 529:167\u2013171",
#         "DOI": "10.1038/nature16489",
#         "doi-asserted-by": "crossref"
#     },
#     {
#         "key": "895_CR12",
#         "first-page": "392",
#         "volume": "62",
#         "author": "R Dolan",
#         "year": "1974",
#         "unstructured": "Dolan R, Howard A, Gallenson A (1974) Man\u2019s impact on the Colorado River in the grand canyon: the grand canyon is being affected both by the vastly changed Colorado River and by the increased presence of man. American Scientist 62:392\u2013401",
#         "journal-title": "American Scientist"
#     },
#     {
#         "key": "895_CR13",
#         "doi-asserted-by": "crossref",
#         "first-page": "23",
#         "DOI": "10.1007/BF00347821",
#         "volume": "38",
#         "author": "LH Doliner",
#         "year": "1979",
#         "unstructured": "Doliner LH, Jolliffe PA (1979) Ecological evidence concerning the adaptive significance of the C4 dicarboxylic acid pathway of photosynthesis. Oecologia 38:23\u201334",
#         "journal-title": "Oecologia"
#     },
#     {
#         "key": "895_CR14",
#         "unstructured": "Dominguez F, Rivera E, Lettenmaier DP, Castro CL (2012) Changes in winter precipitation extremes for the western United States under a warmer climate as simulated by regional climate models. Geophysical Research Letters 39:L05803. doi: 10.1029/2011GL050762",
#         "DOI": "10.1029/2011GL050762",
#         "doi-asserted-by": "publisher"
#     },
#     {
#         "key": "895_CR15",
#         "unstructured": "Flora of North America Editorial Committee, eds. (1993)+. Flora of North America North of Mexico. 20+ vols. New York and Oxford"
#     },
#     {
#         "key": "895_CR16",
#         "unstructured": "Fraser LH, Garris HW & Carlyle CN (2016) Predicting plant trait similarity along enviornmental gradients. Plant Ecol 217:1297-1306",
#         "DOI": "10.1007/s11258-016-0628-3",
#         "doi-asserted-by": "crossref"
#     },
#     {
#         "key": "895_CR17",
#         "unstructured": "Gloss SP, Lovich JE, and Melis TS & eds (2005) The state of the Colorado river ecosystem in grand canyon. U.S. Geological Survey Circular 1282. 220 p., http://pubs.usgs.gov/circ/1282/"
#     },
#     {
#         "key": "895_CR18",
#         "doi-asserted-by": "crossref",
#         "first-page": "1169",
#         "DOI": "10.1086/283244",
#         "volume": "111",
#         "author": "JP Grime",
#         "year": "1977",
#         "unstructured": "Grime JP (1977) Evidence for the existence of three primary strategies in plants and its relevance to ecological and evolutionary theory. The American Naturalist 111:1169\u20131194",
#         "journal-title": "The American Naturalist"
#     },
#     {
#         "key": "895_CR19",
#         "author": "JP Grime",
#         "year": "1979",
#         "unstructured": "Grime JP (1979) Plant strategies and ecological processes. Wiley, Chichester",
#         "volume-title": "Plant strategies and ecological processes"
#     },
#     {
#         "key": "895_CR20",
#         "doi-asserted-by": "crossref",
#         "first-page": "107",
#         "DOI": "10.1111/j.1469-185X.1977.tb01347.x",
#         "volume": "52",
#         "author": "PJ Grubb",
#         "year": "1977",
#         "unstructured": "Grubb PJ (1977) The maintenance of species-richness in plant communities: the importance of the regeneration niche. Biological Reviews 52:107\u2013145",
#         "journal-title": "Biological Reviews"
#     },
#     {
#         "key": "895_CR21",
#         "doi-asserted-by": "crossref",
#         "first-page": "2149",
#         "DOI": "10.1890/0012-9658(2000)081[2149:COSSOP]2.0.CO;2",
#         "volume": "81",
#         "author": "Q Guo",
#         "year": "2000",
#         "unstructured": "Guo Q, Brown JH, Valone TJ, Kachman SD (2000) Constraints of seed size on plant distribution and abundance. Ecology 81:2149\u20132155",
#         "journal-title": "Ecology"
#     },
#     {
#         "key": "895_CR22",
#         "doi-asserted-by": "crossref",
#         "first-page": "457",
#         "DOI": "10.1007/s004420100628",
#         "volume": "126",
#         "author": "UG Hacke",
#         "year": "2001",
#         "unstructured": "Hacke UG, Sperry JS, Pockman WT, Davis SD, McCulloh KA (2001) Trends in wood density and structure are linked to prevention of xylem implosion by negative pressure. Oecologia 126:457\u2013461",
#         "journal-title": "Oecologia"
#     },
#     {
#         "key": "895_CR23",
#         "doi-asserted-by": "crossref",
#         "first-page": "797",
#         "DOI": "10.1111/j.0022-0477.2004.00918.x",
#         "volume": "92",
#         "author": "A Hampe",
#         "year": "2004",
#         "unstructured": "Hampe A (2004) Extensive hydrochory uncouples spatiotemporal patterns of seedfall and seedling recruitment in a \u2018bird-dispersed\u2019riparian tree. Journal of Ecology 92:797\u2013807",
#         "journal-title": "Journal of Ecology"
#     },
#     {
#         "key": "895_CR24",
#         "doi-asserted-by": "crossref",
#         "first-page": "12422",
#         "DOI": "10.1073/pnas.0404500101",
#         "volume": "101",
#         "author": "K Hayhoe",
#         "year": "2004",
#         "unstructured": "Hayhoe K, Cayan D, Field CB, Frumhoff PC, Maurer EP, Miller NL, Moser SC, Schneider SH, Cahill KN, Cleland EE, Dale L, Drapek R, Hanemann RM, Kalkstein LS, Lenihan J, Lunch CK, Neilson RP, Sheridan SC, Verville JH (2004) Emissions pathways, climate change, and impacts on California. Proceedings of the National Academy of Sciences of the United States of America 101:12422\u201312427",
#         "journal-title": "Proceedings of the National Academy of Sciences of the United States of America"
#     },
#     {
#         "key": "895_CR25",
#         "unstructured": "Hazel JE, Kaplinsk, M, Parnell R, Kohl K & Topping DJ (2007) Stage-discharge relations for the Colorado river in Glen, marble, and grand canyons, Arizona, 1990\u20132005. (No. 2006\u20131243). Geological Survey (US). http://pubs.usgs.gov/of/2006/1243/pdf/of06-1243_508.pdf",
#         "DOI": "10.3133/ofr20061243",
#         "doi-asserted-by": "crossref"
#     },
#     {
#         "key": "895_CR26",
#         "author": "TN Hollingsworth",
#         "volume": "8",
#         "year": "2013",
#         "unstructured": "Hollingsworth TN, Johnstone JF, Bernhardt EL, Chapin FS III (2013) Fire severity filters regeneration traits to shape community assembly in Alaska\u2019s boreal forest. PLoS One 8:e56033",
#         "journal-title": "PLoS One",
#         "DOI": "10.1371/journal.pone.0056033",
#         "doi-asserted-by": "crossref"
#     },
#     {
#         "key": "895_CR27",
#         "doi-asserted-by": "crossref",
#         "first-page": "1",
#         "DOI": "10.1890/ES15-00064.1",
#         "volume": "6",
#         "author": "N Hough-Snee",
#         "year": "2015",
#         "unstructured": "Hough-Snee N, Laub BG, Merritt DM, Long AL, Nackley LL, Roper BB, Wheaton JM (2015) Multi-scale environmental filters and niche partitioning govern the distributions of riparian vegetation guilds. Ecosphere 6:1\u201322",
#         "journal-title": "Ecosphere"
#     },
#     {
#         "key": "895_CR28",
#         "doi-asserted-by": "crossref",
#         "first-page": "269",
#         "DOI": "10.1086/628592",
#         "volume": "89",
#         "author": "A Howard",
#         "year": "1981",
#         "unstructured": "Howard A, Dolan R (1981) Geomorphology of the Colorado River in the grand canyon. Journal Geology 89:269\u2013298",
#         "journal-title": "Journal Geology"
#     },
#     {
#         "key": "895_CR29",
#         "unstructured": "Huisinga K, Makarick L, Watters K (2006) River and desert plants of the grand canyon. Mountain Press Publishing Company, Missoula, MT"
#     },
#     {
#         "key": "895_CR30",
#         "doi-asserted-by": "crossref",
#         "first-page": "193",
#         "DOI": "10.1007/s00442-008-0965-6",
#         "volume": "156",
#         "author": "A Ishida",
#         "year": "2008",
#         "unstructured": "Ishida A, Nakano T, Yazaki K, Matsuki S, Koike N, Lauenstein DL, Shimizu M, Yamashita N (2008) Coordination between leaf and stem traits related to leaf carbon gain and hydraulics across 32 drought-tolerant angiosperms. Oecologia 156:193\u2013202",
#         "journal-title": "Oecologia"
#     },
#     {
#         "key": "895_CR31",
#         "unstructured": "JMP\u00ae, Version Pro 13. SAS Institute Inc., Cary, NC"
#     },
#     {
#         "key": "895_CR32",
#         "doi-asserted-by": "crossref",
#         "first-page": "235",
#         "DOI": "10.1111/jvs.12066",
#         "volume": "25",
#         "author": "E Kazakou",
#         "year": "2014",
#         "unstructured": "Kazakou E, Violle C, Roumet C, Navas M, Vile D, Kattge J, Garnier E (2014) Are trait-based species rankings consistent across data sets and spatial scales? Journal of Vegetation Science 25:235\u2013247",
#         "journal-title": "Journal of Vegetation Science"
#     },
#     {
#         "key": "895_CR33",
#         "doi-asserted-by": "crossref",
#         "first-page": "427",
#         "DOI": "10.2307/2259725",
#         "volume": "1",
#         "author": "PR Kemp",
#         "year": "1983",
#         "unstructured": "Kemp PR (1983) Phenological patterns of Chihuahuan Desert plants in relation to the timing of water availability. Journal of Ecology 1:427\u2013436",
#         "journal-title": "Journal of Ecology"
#     },
#     {
#         "key": "895_CR34",
#         "doi-asserted-by": "crossref",
#         "first-page": "793",
#         "DOI": "10.1111/j.1442-9993.2009.01988.x",
#         "volume": "34",
#         "author": "G Kyle",
#         "year": "2009",
#         "unstructured": "Kyle G, Leishman MR (2009) Plant functional trait variation in relation to riparian geomorphology: the importance of disturbance. Austral Ecology 34:793\u2013804",
#         "journal-title": "Austral Ecology"
#     },
#     {
#         "key": "895_CR35",
#         "doi-asserted-by": "crossref",
#         "first-page": "3213",
#         "DOI": "10.1890/13-1965.1",
#         "volume": "95",
#         "author": "E Larios",
#         "year": "2014",
#         "unstructured": "Larios E, B\u00farquez A, Becerra JX, Lawrence Venable D (2014) Natural selection on seed size through the life cycle of a desert annual plant. Ecology 95:3213\u20133220",
#         "journal-title": "Ecology"
#     },
#     {
#         "key": "895_CR36",
#         "doi-asserted-by": "crossref",
#         "first-page": "545",
#         "DOI": "10.1046/j.1365-2435.2002.00664.x",
#         "volume": "16",
#         "author": "S Lavorel",
#         "year": "2002",
#         "unstructured": "Lavorel S, Garnier E (2002) Predicting changes in community composition and ecosystem functioning from plant traits: revisiting the holy grail. Functional Ecology 16:545\u2013556",
#         "journal-title": "Functional Ecology"
#     },
#     {
#         "key": "895_CR37",
#         "doi-asserted-by": "crossref",
#         "first-page": "517",
#         "DOI": "10.2307/2261604",
#         "volume": "83",
#         "author": "MR Leishman",
#         "year": "1995",
#         "unstructured": "Leishman MR, Westoby M, Jurad E (1995) Correlates of seed size variation: a comparison among five temperate floras. Journal of Ecology 83:517\u2013529",
#         "journal-title": "Journal of Ecology"
#     },
#     {
#         "key": "895_CR38",
#         "author": "F Lens",
#         "year": "2016",
#         "unstructured": "Lens F, Picon-Cochard C, Delmas CEL, Signarbieux C, Buttler A, Cochard H, Jansen S, Chauvin T, Doria LC, del Arco M, Delzon S (2016) Herbaceous angiosperms are not more vulnerable to drought-induced embolism than angiosperm trees. Plant Physiology. doi: 10.1104/pp.16.00829",
#         "journal-title": "Plant Physiology",
#         "DOI": "10.1104/pp.16.00829",
#         "doi-asserted-by": "publisher"
#     },
#     {
#         "key": "895_CR39",
#         "doi-asserted-by": "crossref",
#         "first-page": "94",
#         "DOI": "10.1016/j.tree.2003.10.002",
#         "volume": "19",
#         "author": "DA Lytle",
#         "year": "2004",
#         "unstructured": "Lytle DA, Poff NL (2004) Adaptation to natural flow regimes. Trends in Ecology and Evolution 19:94\u2013100",
#         "journal-title": "Trends in Ecology and Evolution"
#     },
#     {
#         "key": "895_CR40",
#         "unstructured": "Magirl CS, Breedlove MJ, Webb RH, & Griffiths PG. (2008) Modeling water-surface elevations and virtual shorelines for the Colorado river in grand canyon, Arizona: U.S. Geological Survey Scientific Investigations Report 2008\u20135075, 32 p., http://pubs.usgs.gov/sir/2008/5075 ."
#     },
#     {
#         "key": "895_CR41",
#         "doi-asserted-by": "crossref",
#         "first-page": "571",
#         "DOI": "10.1111/j.1365-3040.2005.01433.x",
#         "volume": "29",
#         "author": "H Maherali",
#         "year": "2006",
#         "unstructured": "Maherali H, Moura CF, Caldeira MC, Willson CJ, Jackson RB (2006) Functional coordination between leaf gas exchange and vulnerability to xylem cavitation in temperate forest trees. Plant, Cell and Environment 29:571\u2013583",
#         "journal-title": "Plant, Cell and Environment"
#     },
#     {
#         "key": "895_CR42",
#         "unstructured": "McCoy-Sulentic ME, Kolb TE & Palmquist EC (2017) Community-level riparian plant traits, Colorado river, grand canyon, 2013\u20132015 - Data: U.S. Geological Survey data release, doi: 10.5066/F73R0R24 .",
#         "DOI": "10.5066/F73R0R24",
#         "doi-asserted-by": "publisher"
#     },
#     {
#         "issue": "1",
#         "key": "895_CR43",
#         "first-page": "46",
#         "volume": "46",
#         "author": "SP McLaughlin",
#         "year": "1986",
#         "unstructured": "McLaughlin SP (1986) Floristic analysis of the southwestern United States. Great Basin Naturalist 46(1):46\u201365",
#         "journal-title": "Great Basin Naturalist"
#     },
#     {
#         "key": "895_CR44",
#         "doi-asserted-by": "crossref",
#         "first-page": "1973",
#         "DOI": "10.1890/12-0303.1",
#         "volume": "22",
#         "author": "D Merritt",
#         "year": "2012",
#         "unstructured": "Merritt D, Bateman HL (2012) Linking stream flow and groundwater to avian habitat in a desert riparian system. Ecological Applications 22:1973\u20131988",
#         "journal-title": "Ecological Applications"
#     },
#     {
#         "key": "895_CR45",
#         "doi-asserted-by": "crossref",
#         "first-page": "206",
#         "DOI": "10.1111/j.1365-2427.2009.02206.x",
#         "volume": "55",
#         "author": "DM Merritt",
#         "year": "2010",
#         "unstructured": "Merritt DM, Scott ML, Poff LN, Auble GT, Lytle DA (2010) Theory, methods and tools for determining environmental flows for riparian vegetation: riparian vegetation-flow response guilds. Freshwater Biology 55:206\u2013225",
#         "journal-title": "Freshwater Biology"
#     },
#     {
#         "key": "895_CR46",
#         "doi-asserted-by": "crossref",
#         "first-page": "838",
#         "DOI": "10.1111/j.1461-0248.2010.01476.x",
#         "volume": "13",
#         "author": "J Messier",
#         "year": "2010",
#         "unstructured": "Messier J, McGill BJ, Lechowicz MJ (2010) How do traits vary across ecological scales? A case for trait-based ecology. Ecology Letters 13:838\u2013848",
#         "journal-title": "Ecology Letters"
#     },
#     {
#         "key": "895_CR47",
#         "doi-asserted-by": "crossref",
#         "first-page": "337",
#         "DOI": "10.1111/j.1469-8137.2007.02166.x",
#         "volume": "176",
#         "author": "L Mommer",
#         "year": "2007",
#         "unstructured": "Mommer L, Wolters-Arts M, Andersen C, Visser EJW, Pedersen O (2007) Submergence-induced leaf acclimation in terrestrial species varying in flooding tolerance. The New Phytologist 176:337\u2013345",
#         "journal-title": "The New Phytologist"
#     },
#     {
#         "key": "895_CR48",
#         "doi-asserted-by": "crossref",
#         "first-page": "209",
#         "DOI": "10.2307/1941822",
#         "volume": "3",
#         "author": "RJ Naiman",
#         "year": "1993",
#         "unstructured": "Naiman RJ, Decamps H, Pollock M (1993) The role of riparian corridors in maintaining regional biodiversity. Ecological Applications 3:209\u2013212",
#         "journal-title": "Ecological Applications"
#     },
#     {
#         "key": "895_CR49",
#         "doi-asserted-by": "crossref",
#         "first-page": "468",
#         "DOI": "10.1007/s00267-002-2735-2",
#         "volume": "30",
#         "author": "C Nilsson",
#         "year": "2002",
#         "unstructured": "Nilsson C, Svedmark M (2002) Basic principles and ecological consequences of changing water regimes: riparian plant communities. Environmental Management 30:468\u2013480",
#         "journal-title": "Environmental Management"
#     },
#     {
#         "key": "895_CR50",
#         "doi-asserted-by": "crossref",
#         "first-page": "264",
#         "DOI": "10.1111/geb.12123",
#         "volume": "23",
#         "author": "A Ordonez",
#         "year": "2014",
#         "unstructured": "Ordonez A (2014) Global meta-analysis of trait consistency of non-native plants between their native and introduced areas. Global Ecology and Biogeography 23:264\u2013273",
#         "journal-title": "Global Ecology and Biogeography"
#     },
#     {
#         "key": "895_CR51",
#         "doi-asserted-by": "crossref",
#         "first-page": "22",
#         "DOI": "10.3398/064.077.0104",
#         "volume": "77",
#         "author": "EC Palmquist",
#         "year": "2017",
#         "unstructured": "Palmquist EC, Ralston BE, Sarr D, Merritt D, Shafroth PB, Scott JA (2017) Functional traits and ecological affinities of riparian plants along the Colorado River in grand canyon. Western North American Naturalist 77:22\u201330",
#         "journal-title": "Western North American Naturalist"
#     },
#     {
#         "key": "895_CR52",
#         "doi-asserted-by": "crossref",
#         "first-page": "167",
#         "DOI": "10.1071/BT12225",
#         "volume": "61",
#         "author": "N P\u00e9rez-Harguindeguy",
#         "year": "2013",
#         "unstructured": "P\u00e9rez-Harguindeguy N, D\u00edaz S, Garnier E, Lavorel S, Poorter H, Jaureguiberry P, Bret-Harte MS, Cornwell WK, Craine JM, Gurvich DE (2013) New handbook for standardised measurement of plant functional traits worldwide. Australian Journal of Botany 61:167\u2013234",
#         "journal-title": "Australian Journal of Botany"
#     },
#     {
#         "key": "895_CR53",
#         "doi-asserted-by": "crossref",
#         "first-page": "1287",
#         "DOI": "10.2307/2656722",
#         "volume": "87",
#         "author": "WT Pockman",
#         "year": "2000",
#         "unstructured": "Pockman WT, Sperry JS (2000) Vulnerability to xylem cavitation and the distribution of Sonoran Desert vegetation. American Journal of Botany 87:1287\u20131299",
#         "journal-title": "American Journal of Botany"
#     },
#     {
#         "key": "895_CR54",
#         "doi-asserted-by": "crossref",
#         "first-page": "1733",
#         "DOI": "10.1890/0012-9658(2006)87[1733:LTAGPO]2.0.CO;2",
#         "volume": "87",
#         "author": "L Poorter",
#         "year": "2006",
#         "unstructured": "Poorter L, Bongers F (2006) Leaf traits are good predictors of plant performance across 53 rain forest species. Ecology 87:1733\u20131743",
#         "journal-title": "Ecology"
#     },
#     {
#         "key": "895_CR55",
#         "doi-asserted-by": "crossref",
#         "first-page": "807",
#         "DOI": "10.1111/j.1469-8137.2006.01712.x",
#         "volume": "170",
#         "author": "KA Preston",
#         "year": "2006",
#         "unstructured": "Preston KA, Cornwell WK, DeNoyer JL (2006) Wood density and vessel traits as distinct correlates of ecological strategy in 51 California coast range angiosperms. The New Phytologist 170:807\u2013818",
#         "journal-title": "The New Phytologist"
#     },
#     {
#         "key": "895_CR56",
#         "doi-asserted-by": "crossref",
#         "first-page": "65",
#         "DOI": "10.1046/j.1365-2664.2003.00762.x",
#         "volume": "40",
#         "author": "RF Pywell",
#         "year": "2003",
#         "unstructured": "Pywell RF, Bullock JM, Roy DB, Warman LIZ, Walker KJ, Rothery P (2003) Plant traits as predictors of performance in ecological restoration. Journal of Applied Ecology 40:65\u201377",
#         "journal-title": "Journal of Applied Ecology"
#     },
#     {
#         "key": "895_CR57",
#         "unstructured": "Ralston BE, Starfield AM, Black RS & Van Lonkhuyzen RA (2014) State-and-transition prototype model of riparian vegetation downstream of Glen Canyon Dam, Arizona. No. 2014\u20131095. US Geological Survey. doi: 10.3133/ofr20141095 .",
#         "DOI": "10.3133/ofr20141095",
#         "doi-asserted-by": "publisher"
#     },
#     {
#         "key": "895_CR58",
#         "doi-asserted-by": "crossref",
#         "first-page": "275",
#         "DOI": "10.1111/1365-2745.12211",
#         "volume": "102",
#         "author": "PB Reich",
#         "year": "2014",
#         "unstructured": "Reich PB (2014) The worldwide 'fast-slow' plant economics spectrum: a traits manifesto. Journal of Ecology 102:275\u2013301",
#         "journal-title": "Journal of Ecology"
#     },
#     {
#         "key": "895_CR59",
#         "unstructured": "Royal Botanic Gardens Kew. (2016) Seed Information Database (SID). Version 7.1. Available from: http://data.kew.org/sid/ (August 2016)"
#     },
#     {
#         "key": "895_CR60",
#         "first-page": "41",
#         "volume": "161",
#         "author": "RF Sage",
#         "year": "2004",
#         "unstructured": "Sage RF (2004) The evolution of C4 photosynthesis. The New Phytologist 161:41\u2013370",
#         "journal-title": "The New Phytologist"
#     },
#     {
#         "key": "895_CR61",
#         "doi-asserted-by": "crossref",
#         "first-page": "1",
#         "DOI": "10.1890/ES10-00175.1",
#         "volume": "2",
#         "author": "B Sandel",
#         "year": "2011",
#         "unstructured": "Sandel B, Corbin JD, Krupa M (2011) Using plant functional traits to guide restoration: a case study in California coastal grassland. Ecosphere 2:1\u201316",
#         "journal-title": "Ecosphere"
#     },
#     {
#         "key": "895_CR62",
#         "first-page": "1532",
#         "volume": "120",
#         "author": "JB Sankey",
#         "year": "2015",
#         "unstructured": "Sankey JB, Ralston BE, Grams PE, Schmidt JC, Cagney LE (2015) Riparian vegetation, Colorado River, and climate: five decades of spatiotemporal dynamics in the grand canyon with river regulation. Journal of Geophysical Research: Biogeosciences 120:1532\u20131547",
#         "journal-title": "Journal of Geophysical Research: Biogeosciences"
#     },
#     {
#         "key": "895_CR63",
#         "doi-asserted-by": "crossref",
#         "first-page": "709",
#         "DOI": "10.1086/629435",
#         "volume": "98",
#         "author": "JC Schmidt",
#         "year": "1990",
#         "unstructured": "Schmidt JC (1990) Recirculating flow and sedimentation in the Colorado River in grand canyon, Arizona. Journal of Geology 98:709\u2013724",
#         "journal-title": "Journal of Geology"
#     },
#     {
#         "key": "895_CR64",
#         "doi-asserted-by": "crossref",
#         "first-page": "21277",
#         "DOI": "10.1073/pnas.0910856107",
#         "volume": "107",
#         "author": "R Seager",
#         "year": "2010",
#         "unstructured": "Seager R, Vecchi GA (2010) Greenhouse warming and the 21st century hydroclimate of southwestern North America. Proceedings of the National Academy of Sciences of the United States of America 107:21277\u201321282",
#         "journal-title": "Proceedings of the National Academy of Sciences of the United States of America"
#     },
#     {
#         "key": "895_CR65",
#         "doi-asserted-by": "crossref",
#         "first-page": "1181",
#         "DOI": "10.1126/science.1139601",
#         "volume": "316",
#         "author": "R Seager",
#         "year": "2007",
#         "unstructured": "Seager R, Ting M, Held I, Kushnir Y, Lu J, Vecchi G, Huang HP, Harnik N, Leetmaa A, Lau NC, Li C, Velez J, Naik N (2007) Model projections of an imminent transition to a more arid climate in southwestern North America. Science 316:1181\u20131184",
#         "journal-title": "Science"
#     },
#     {
#         "key": "895_CR66",
#         "doi-asserted-by": "crossref",
#         "first-page": "107",
#         "DOI": "10.1890/1051-0761(2002)012[0107:RVRTAD]2.0.CO;2",
#         "volume": "12",
#         "author": "PB Shafroth",
#         "year": "2002",
#         "unstructured": "Shafroth PB, Stromberg JC, Patten DT (2002) Riparian vegetation response to altered disturbance and stress regimes. Ecological Applications 12:107\u2013123",
#         "journal-title": "Ecological Applications"
#     },
#     {
#         "key": "895_CR67",
#         "doi-asserted-by": "crossref",
#         "first-page": "923",
#         "DOI": "10.1007/s00442-016-3549-x",
#         "volume": "180",
#         "author": "B Shipley",
#         "year": "2016",
#         "unstructured": "Shipley B, De Bello F, Cornelissen JHC, Lalibert\u00e9 E, Laughlin DC, Reich PB (2016) Reinforcing loose foundation stones in trait-based plant ecology. Oecologia 180:923\u2013931",
#         "journal-title": "Oecologia"
#     },
#     {
#         "key": "895_CR68",
#         "doi-asserted-by": "crossref",
#         "first-page": "115",
#         "DOI": "10.1023/B:VEGE.0000026335.44232.1c",
#         "volume": "173",
#         "author": "W Sluis",
#         "year": "2004",
#         "unstructured": "Sluis W, Tandarich J (2004) Siltation and hydrologic regime determine species composition in herbaceous floodplain communities. Plant Ecology 173:115\u2013124",
#         "journal-title": "Plant Ecology"
#     },
#     {
#         "key": "895_CR69",
#         "doi-asserted-by": "crossref",
#         "first-page": "675",
#         "DOI": "10.1006/anbo.2000.1173",
#         "volume": "86",
#         "author": "BK Sorrell",
#         "year": "2000",
#         "unstructured": "Sorrell BK, Mendelssohn IA, McKee KL, Woods RA (2000) Ecophysiology of wetland plant roots: a modelling comparison of aeration in relation to species distribution. Annals of Botany 86:675\u2013685",
#         "journal-title": "Annals of Botany"
#     },
#     {
#         "key": "895_CR70",
#         "doi-asserted-by": "crossref",
#         "first-page": "1025",
#         "DOI": "10.2307/2269352",
#         "volume": "5",
#         "author": "LE Stevens",
#         "year": "1995",
#         "unstructured": "Stevens LE, Schmidt JC, Ayers TJ, Brown BT (1995) Flow regulation, geomorphology, and Colorado River marsh development in the grand canyon, Arizona. Ecological Applications 5:1025\u20131039",
#         "journal-title": "Ecological Applications"
#     },
#     {
#         "key": "895_CR71",
#         "doi-asserted-by": "crossref",
#         "first-page": "1",
#         "DOI": "10.1016/j.jaridenv.2013.02.004",
#         "volume": "94",
#         "author": "JC Stromberg",
#         "year": "2013",
#         "unstructured": "Stromberg JC (2013) Root patterns and hydrogeomorphic niches of riparian plants in the American southwest. Journal of Arid Environments 94:1\u20139",
#         "journal-title": "Journal of Arid Environments"
#     },
#     {
#         "key": "895_CR72",
#         "doi-asserted-by": "crossref",
#         "first-page": "651",
#         "DOI": "10.1111/j.1365-2427.2006.01713.x",
#         "volume": "52",
#         "author": "JC Stromberg",
#         "year": "2007",
#         "unstructured": "Stromberg JC, Beauchamp VB, Dixon MD, Lite SJ, Paradzick C (2007) Importance of low-flow and high-flow characteristics to restoration of riparian vegetation along rivers in arid South-Western United States. Freshwater Biology 52:651\u2013679",
#         "journal-title": "Freshwater Biology"
#     },
#     {
#         "key": "895_CR73",
#         "doi-asserted-by": "crossref",
#         "first-page": "205",
#         "DOI": "10.1111/j.1365-2435.2007.01375.x",
#         "volume": "22",
#         "author": "JC Stromberg",
#         "year": "2008",
#         "unstructured": "Stromberg JC, Boudell JA, Hazelton AF (2008) Differences in seed mass between hydric and xeric plants influence seed bank dynamics in a dryland riparian ecosystem. Functional Ecology 22:205\u2013212",
#         "journal-title": "Functional Ecology"
#     },
#     {
#         "key": "895_CR74",
#         "doi-asserted-by": "crossref",
#         "first-page": "2234",
#         "DOI": "10.1890/09-1743.1",
#         "volume": "91",
#         "author": "NG Swenson",
#         "year": "2010",
#         "unstructured": "Swenson NG, Weiser MD (2010) Plant geography upon the basis of functional traits: an example from eastern north American trees. Ecology 91:2234\u20132241",
#         "journal-title": "Ecology"
#     },
#     {
#         "key": "895_CR75",
#         "doi-asserted-by": "crossref",
#         "first-page": "311",
#         "DOI": "10.2307/3669716",
#         "volume": "21",
#         "author": "JP Syvertsen",
#         "year": "1976",
#         "unstructured": "Syvertsen JP, Nickell GL, Spellenberg RW, Cunningham GL (1976) Carbon reduction pathways and standing crop in three Chihuahuan Desert plant communities. The Southwestern Naturalist 21:311\u2013320",
#         "journal-title": "The Southwestern Naturalist"
#     },
#     {
#         "key": "895_CR76",
#         "doi-asserted-by": "crossref",
#         "first-page": "1",
#         "DOI": "10.1007/BF00351210",
#         "volume": "23",
#         "author": "JA Teeri",
#         "year": "1976",
#         "unstructured": "Teeri JA, Stowe LG (1976) Climatic patterns and the distribution of C4 grasses in North America. Oecologia 23:1\u201312",
#         "journal-title": "Oecologia"
#     },
#     {
#         "key": "895_CR77",
#         "unstructured": "Topping DJ, Schmidt JC, & Vierra LE (2003). Computation and analysis of the instantaneous-discharge record for the Colorado River at Lees Ferry, Arizona: May 8, 1921, through September 30, 2000 (p. 118). US Geological Survey Professional Paper 1677. http://pubs.usgs.gov/pp/pp1677/pdf/pp1677.pdf ."
#     },
#     {
#         "key": "895_CR78",
#         "author": "RM Turner",
#         "year": "1980",
#         "unstructured": "Turner RM, Karpiscak MM (1980) Recent vegetation changes along the Colorado River between Glen canyon dam and Lake mead. Arizona, US Geological Survey Report",
#         "volume-title": "Recent vegetation changes along the Colorado River between Glen canyon dam and Lake mead"
#     },
#     {
#         "key": "895_CR79",
#         "author": "U.S Department of the Interior",
#         "year": "1996",
#         "unstructured": "U.S Department of the Interior (1996) Record of Decision, Operation of Glen Canyon Dam: Final Environmental Impact Statement, pp15, Office of the Secretary of the Interior. Bureau of Reclamation, Washington, D.C. http://www.usbr.gov/uc/rm/amp/pdfs/sp_appndxG_ROD.pdf",
#         "volume-title": "Record of Decision, Operation of Glen Canyon Dam: Final Environmental Impact Statement, pp15, Office of the Secretary of the Interior"
#     },
#     {
#         "key": "895_CR80",
#         "doi-asserted-by": "crossref",
#         "first-page": "213",
#         "DOI": "10.1111/j.1469-8137.2006.01692.x",
#         "volume": "170",
#         "author": "L Voesenek",
#         "year": "2006",
#         "unstructured": "Voesenek L, Colmer TD, Pierik R, Millenaar FF, Peeters AJM (2006) How plants cope with complete submergence. The New Phytologist 170:213\u2013226",
#         "journal-title": "The New Phytologist"
#     },
#     {
#         "key": "895_CR81",
#         "doi-asserted-by": "crossref",
#         "first-page": "459",
#         "DOI": "10.1046/j.1469-8137.2000.00775.x",
#         "volume": "148",
#         "author": "S Wahl",
#         "year": "2000",
#         "unstructured": "Wahl S, Ryer P (2000) Root tissue structure is linked to ecological strategies of grasses. The New Phytologist 148:459\u2013471",
#         "journal-title": "The New Phytologist"
#     },
#     {
#         "key": "895_CR82",
#         "doi-asserted-by": "crossref",
#         "first-page": "12",
#         "DOI": "10.2307/3897378",
#         "volume": "1",
#         "author": "SS Waller",
#         "year": "1979",
#         "unstructured": "Waller SS, Lewis JK (1979) Occurrence of C3 and C4 photosynthetic pathways in north American grasses. Journal of Range Management 1:12\u201328",
#         "journal-title": "Journal of Range Management"
#     },
#     {
#         "key": "895_CR83",
#         "unstructured": "Weiher E, Werk A, Thompson K, Roderick M, Garnier E & Eriksson O (1999) Challenging Theophrastus: a common core list of plant traits for functional ecology. J Veg Sci 10:609-620",
#         "DOI": "10.2307/3237076",
#         "doi-asserted-by": "crossref"
#     },
#     {
#         "key": "895_CR84",
#         "unstructured": "Welsh SL, Atwood ND, Goodrich S, Higgins LC (2003) A Utah Flora. Monte Bean Life Science Museum, Provo, UT"
#     },
#     {
#         "key": "895_CR85",
#         "doi-asserted-by": "crossref",
#         "first-page": "213",
#         "DOI": "10.1023/A:1004327224729",
#         "volume": "199",
#         "author": "M Westoby",
#         "year": "1998",
#         "unstructured": "Westoby M (1998) A leaf-height-seed (LHS) plant ecology strategy scheme. Plant and Soil 199:213\u2013227",
#         "journal-title": "Plant and Soil"
#     },
#     {
#         "key": "895_CR86",
#         "doi-asserted-by": "crossref",
#         "first-page": "261",
#         "DOI": "10.1016/j.tree.2006.02.004",
#         "volume": "21",
#         "author": "M Westoby",
#         "year": "2006",
#         "unstructured": "Westoby M, Wright IJ (2006) Land-plant ecology on the basis of functional traits. Trends in Ecology and Evolution 21:261\u2013268",
#         "journal-title": "Trends in Ecology and Evolution"
#     },
#     {
#         "key": "895_CR87",
#         "doi-asserted-by": "crossref",
#         "first-page": "368",
#         "DOI": "10.1016/0169-5347(92)90006-W",
#         "volume": "7",
#         "author": "M Westoby",
#         "year": "1992",
#         "unstructured": "Westoby M, Jurado E, Leishman M (1992) Comparative evolutionary ecology of seed size. Trends in Ecology and Evolution 7:368\u2013372",
#         "journal-title": "Trends in Ecology and Evolution"
#     },
#     {
#         "key": "895_CR88",
#         "doi-asserted-by": "crossref",
#         "first-page": "519",
#         "DOI": "10.3732/ajb.0900243",
#         "volume": "97",
#         "author": "GB Williamson",
#         "year": "2010",
#         "unstructured": "Williamson GB, Wiemann MC (2010) Measuring wood specific gravity...Correctly. American Journal of Botany 97:519\u2013524",
#         "journal-title": "American Journal of Botany"
#     },
#     {
#         "key": "895_CR89",
#         "doi-asserted-by": "crossref",
#         "first-page": "821",
#         "DOI": "10.1038/nature02403",
#         "volume": "428",
#         "author": "IJ Wright",
#         "year": "2004",
#         "unstructured": "Wright IJ, Reich PB, Westoby M, Ackerly DD, Baruch Z, Bongers F, Cavender-Bares J, Chapin T, Cornelissen JHC, Diemer M, Flexas J, Garnier E, Groom PK, Gulias J, Hikosaka K, Lamont BB, Lee T, Lee W, Lusk C, Midgley JJ (2004) The worldwide leaf economics spectrum. Nature 428:821\u2013827",
#         "journal-title": "Nature"
#     }
# ]

# %% [markdown]
# ## For Internship Project
#
# The USGS intern can expand on lessons on [pandas dataframes](https://www.earthdatascience.org/courses/intro-to-earth-data-science/scientific-data-structures-python/pandas-dataframes/), [loops](https://www.earthdatascience.org/courses/intro-to-earth-data-science/write-efficient-python-code/loops/), and [dictionaries](https://realpython.com/python-dicts/) ([interactive tutorial option](https://www.learnpython.org/en/Dictionaries)) to write a loop that will iterate the following code to store the information returned by the API to a new pandas dataframe.

# %%
# Create empty list to store information that will be converted to dataframe
list_to_df = []

# %%
# Add items to list
list_to_df.append([result["message"]["DOI"],
                  result["message"]["published-online"]["date-parts"][0][0], 
                  result["message"]["title"][0],
                  result["message"]["publisher"]
                  ])

# %%
# Convert list to dataframe
df = pd.DataFrame(list_to_df, columns=["doi", "year", "title", "publisher"])

df
# Out:
#                          doi  year  \
# 0  10.1007/s13157-017-0895-3  2017
#
#                                                title  \
# 0  Changes in Community-Level Riparian Plant Trai...
#
#                                  publisher
# 0  Springer Science and Business Media LLC

# %% [markdown]
# ## Possible Expansion of Work
#
# Another related aspect of this work would be to query the data release doi in [geodeepdive](https://geodeepdive.org/api/snippets?term=10.5066/F71G0JF6) and identify whether the publication listed in the spreadsheet (rel_pub_url) is associated with the data release doi and/or whether there are other publications associated wit the data release doi.
#
# For the case of `rel_pub_url = '10.3133/sim3378'` (row 4 in the USGS spreadsheet), the publication url was found associated with the data release doi: `https://geodeepdive.org/api/snippets?term=10.5066/F71G0JF6`.
