# %%
from pprintjson import pprintjson as ppjson 
import pandas as pd 
from habanero import Crossref
import os 
import earthpy as et 
from urllib.error import HTTPError
import matplotlib.pyplot as plt

# %%
os.chdir(os.path.join(et.io.HOME, "documents", "work"))
os.getcwd()
# Out:
# 'C:\\Users\\Taylor Hunt\\documents\\work'

# %%
file_name = os.path.join("doi_dr_pubs1.csv")
dr_doi_pubs1 = pd.read_csv(file_name)
dr_doi_pubs1
# Out:
#         ID                dr_doi  primary  \
# 0        0  doi:10.5066/P90QU56J     True
# 1        1  doi:10.5066/F73R0R24     True
# 2        2  doi:10.5066/F7VQ30RM     True
# 3        3  doi:10.5066/F71G0JF6     True
# 4        4  doi:10.5066/F7571931     True
# ...    ...                   ...      ...
# 1349  1349  doi:10.5066/P9D5IP0G     True
# 1350  1350  doi:10.5066/F7JH3KBD     True
# 1351  1351  doi:10.5066/P9V9AORH     True
# 1352  1352  doi:10.5066/P9BS882S     True
# 1353  1353  doi:10.5066/P9T6P5SM     True
#
#                                        rel_pub_url rel_pub_has_ref  \
# 0          https://doi.org/10.1021/acs.est.8b07227           False
# 1        https://doi.org/10.1007/s13157-017-0895-3            True
# 2                 https://doi.org/10.1002/etc.3391            True
# 3                  https://doi.org/10.3133/sim3378           False
# 4              https://doi.org/10.3133/sir20155164           False
# ...                                            ...             ...
# 1349     https://doi.org/10.1186/s40462-019-0178-0            True
# 1350           https://doi.org/10.3133/sir20175135           False
# 1351  https://doi.org/10.1371/journal.pone.0197584            True
# 1352               https://doi.org/10.3133/sim3423           False
# 1353           https://doi.org/10.3133/ofr20191086           False
#
#                                            journal_name  \
# 0     Mercury Exposure and Altered Parental Nesting ...
# 1     Changes in Community-Level Riparian Plant Trai...
# 2     Spatial and temporal variation in microcystin ...
# 3     Hydrogeologic characteristics and geospatial a...
# 4     Volcanic aquifers of Hawai‘i—Hydrogeology, wat...
# ...                                                 ...
# 1349  Tropical cyclones alter short-term activity pa...
# 1350  Hydrogeology of, simulation of groundwater flo...
# 1351  Isotope niche dimension and trophic overlap be...
# 1352  Delineation of selected lithologic units using...
# 1353  Estimated use of water in Georgia for 2015 and...
#
#                                     publisher  \
# 0             American Chemical Society (ACS)
# 1     Springer Science and Business Media LLC
# 2                                       Wiley
# 3                        US Geological Survey
# 4                        US Geological Survey
# ...                                       ...
# 1349  Springer Science and Business Media LLC
# 1350                     US Geological Survey
# 1351         Public Library of Science (PLoS)
# 1352                     US Geological Survey
# 1353                     US Geological Survey
#
#                         date published
# 0      {'date-parts': [[2019, 3, 29]]}
# 1      {'date-parts': [[2017, 3, 17]]}
# 2       {'date-parts': [[2016, 6, 6]]}
# 3             {'date-parts': [[2017]]}
# 4             {'date-parts': [[2018]]}
# ...                                ...
# 1349  {'date-parts': [[2019, 10, 28]]}
# 1350          {'date-parts': [[2018]]}
# 1351   {'date-parts': [[2018, 5, 21]]}
# 1352          {'date-parts': [[2019]]}
# 1353          {'date-parts': [[2019]]}
#
# [1354 rows x 8 columns]

# %%
cr = Crossref()
result = cr.works(ids = '10.1021/acs.est.8b07227')
ppjson(result)
# Out:
# {
#     "status": "ok",
#     "message-type": "work",
#     "message-version": "1.0.0",
#     "message": {
#         "indexed": {
#             "date-parts": [
#                 [
#                     2020,
#                     4,
#                     24
#                 ]
#             ],
#             "date-time": "2020-04-24T19:23:29Z",
#             "timestamp": 1587756209612
#         },
#         "reference-count": 67,
#         "publisher": "American Chemical Society (ACS)",
#         "issue": "9",
#         "funder": [
#             {
#                 "DOI": "10.13039/100007149",
#                 "name": "U.S. Bureau of Land Management",
#                 "doi-asserted-by": "publisher",
#                 "award": []
#             },
#             {
#                 "DOI": "10.13039/100000203",
#                 "name": "U.S. Geological Survey",
#                 "doi-asserted-by": "publisher",
#                 "award": []
#             }
#         ],
#         "content-domain": {
#             "domain": [],
#             "crossmark-restriction": false
#         },
#         "short-container-title": [
#             "Environ. Sci. Technol."
#         ],
#         "published-print": {
#             "date-parts": [
#                 [
#                     2019,
#                     5,
#                     7
#                 ]
#             ]
#         },
#         "DOI": "10.1021/acs.est.8b07227",
#         "type": "journal-article",
#         "created": {
#             "date-parts": [
#                 [
#                     2019,
#                     3,
#                     29
#                 ]
#             ],
#             "date-time": "2019-03-29T10:53:35Z",
#             "timestamp": 1553856815000
#         },
#         "page": "5396-5405",
#         "source": "Crossref",
#         "is-referenced-by-count": 2,
#         "title": [
#             "Mercury Exposure and Altered Parental Nesting Behavior in a Wild Songbird"
#         ],
#         "prefix": "10.1021",
#         "volume": "53",
#         "author": [
#             {
#                 "ORCID": "http://orcid.org/0000-0002-7222-1633",
#                 "authenticated-orcid": true,
#                 "given": "C. Alex",
#                 "family": "Hartman",
#                 "sequence": "first",
#                 "affiliation": [
#                     {
#                         "name": "U.S. Geological Survey, Western Ecological Research Center, Dixon Field Station, 800 Business Park Drive, Suite D, Dixon, California 95620, United States"
#                     }
#                 ]
#             },
#             {
#                 "ORCID": "http://orcid.org/0000-0002-3074-8322",
#                 "authenticated-orcid": true,
#                 "given": "Joshua T.",
#                 "family": "Ackerman",
#                 "sequence": "additional",
#                 "affiliation": [
#                     {
#                         "name": "U.S. Geological Survey, Western Ecological Research Center, Dixon Field Station, 800 Business Park Drive, Suite D, Dixon, California 95620, United States"
#                     }
#                 ]
#             },
#             {
#                 "given": "Mark P.",
#                 "family": "Herzog",
#                 "sequence": "additional",
#                 "affiliation": [
#                     {
#                         "name": "U.S. Geological Survey, Western Ecological Research Center, Dixon Field Station, 800 Business Park Drive, Suite D, Dixon, California 95620, United States"
#                     }
#                 ]
#             }
#         ],
#         "member": "316",
#         "published-online": {
#             "date-parts": [
#                 [
#                     2019,
#                     3,
#                     29
#                 ]
#             ]
#         },
#         "container-title": [
#             "Environmental Science & Technology"
#         ],
#         "original-title": [],
#         "language": "en",
#         "link": [
#             {
#                 "URL": "https://pubs.acs.org/doi/pdf/10.1021/acs.est.8b07227",
#                 "content-type": "unspecified",
#                 "content-version": "vor",
#                 "intended-application": "similarity-checking"
#             }
#         ],
#         "deposited": {
#             "date-parts": [
#                 [
#                     2020,
#                     4,
#                     9
#                 ]
#             ],
#             "date-time": "2020-04-09T16:16:29Z",
#             "timestamp": 1586448989000
#         },
#         "score": 1.0,
#         "subtitle": [],
#         "short-title": [],
#         "issued": {
#             "date-parts": [
#                 [
#                     2019,
#                     3,
#                     29
#                 ]
#             ]
#         },
#         "references-count": 67,
#         "journal-issue": {
#             "published-online": {
#                 "date-parts": [
#                     [
#                         2019,
#                         4,
#                         19
#                     ]
#                 ]
#             },
#             "published-print": {
#                 "date-parts": [
#                     [
#                         2019,
#                         5,
#                         7
#                     ]
#                 ]
#             },
#             "issue": "9"
#         },
#         "alternative-id": [
#             "10.1021/acs.est.8b07227"
#         ],
#         "URL": "http://dx.doi.org/10.1021/acs.est.8b07227",
#         "relation": {},
#         "ISSN": [
#             "0013-936X",
#             "1520-5851"
#         ],
#         "issn-type": [
#             {
#                 "value": "0013-936X",
#                 "type": "print"
#             },
#             {
#                 "value": "1520-5851",
#                 "type": "electronic"
#             }
#         ],
#         "subject": [
#             "General Chemistry",
#             "Environmental Chemistry"
#         ]
#     }
# }
